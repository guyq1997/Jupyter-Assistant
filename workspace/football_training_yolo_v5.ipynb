# %%
import clearml clearml.browser_login()

# %%
from clearml import StorageManager, Dataset,Tasktask = Task.init(project_name='football-analysis', task_name = 'test-task2')

# %%
# !pwd

# %%
from ultralytics import YOLO
# Step 2: Selecting the YOLOv8 Model
model_variant = "yolov8n"
task.set_parameter("model_variant", model_variant)

# Step 3: Loading the YOLOv8 Model
model = YOLO(f"{model_variant}.pt")

# Step 4: Setting Up Training Arguments
args = dict(data="football-cv-1/data.yaml", epochs=10, imgsz=640)
task.connect(args)

# Step 5: Initiating Model Training
results = model.train(**args)

# %%
dataset = Dataset.create(
    dataset_project="football-analysis", dataset_name="football-images"
)

# add the example csv
dataset.add_files(path='/home/studio-lab-user/football-cv/football-cv-1/football-cv-1/')

# Upload dataset to ClearML server (customizable)
dataset.upload()

# commit dataset changes
dataset.finalize()

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
